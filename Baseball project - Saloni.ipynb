# %% [markdown]
# # Problem Statement

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# - Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# - Output: Number of predicted wins (W)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
ds=pd.read_csv('baseball.csv')
df=pd.DataFrame(ds)
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Checking Missing Values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Let's plot the heatmap to see the null values.

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %% [markdown]
# There are no null values in the dataset.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# All the variables are integar or float type. There is no categorical variable in this dataset. So we do not need to use Label Encoder or One Hot encoder.

# %% [markdown]
# # Analysis of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# There are total 16 variables in the dataset. One is output variable i.e. W, rest 15 are input variables.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# - We have total 16 input variables, 1 output variable (W) and 30 rows in our dataset.
# - Some of the fields like SO, RA, ER, AB, R, H have very high standard deviation indicating that data is scattered.

# %% [markdown]
# # Plotting of data

# %%
df.plot(kind='density',subplots=True,layout=(6,3),sharex=False, legend=False, fontsize=1,figsize=(15,14))
plt.show()

# %% [markdown]
# From the above plots, we can see that skewness is there in some of the columns in our dataset. We will be removing skewness in further steps.

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(df)

# %% [markdown]
# The above graphs are difficult to read and interpret the relationship between different variables. Lets use correlation to find how they are related to each other.

# %% [markdown]
# # Checking Correlation

# %%
corr_mat=df.corr()
plt.figure(figsize=(22,12))
sns.heatmap(corr_mat,annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# - The above matrix shows the correlation between different variables in the dataset including the target variable.
# - These correlation values can be positive or negative.
# - The positive values indicates the positive correlation and negative values indicates the negative correlation.
# - Positive values indicate that the value of one variable increases with increase in other variable.
# - Negative values indicate that the value of one variable decreases with increase in other variable.
# - The columns with very less correlation with the target variable can be dropped if required.
# - The columns 'RA', 'ER' and 'ERA' are most highly correlated with the target variable.
#
# To see the relationship between each variable and target variable more clearly, we can follow below step.

# %%
corr_matrix=df.corr()
corr_matrix['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# - The above values show correlation of each variable with the target variable.
# - Some variables have positive correlation value while some have negative correlation values.
# - ER, RA, ERA are most highly correlated with the target variable.
# - H, CG, AB and E least correlated with the target variable.

# %% [markdown]
# # Checking Outliers

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
#another way for plotting boxplots
df.plot(kind='box',layout=(6,3), figsize=(15,15),widths=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are outliers present in some columns in the dataset.

# %% [markdown]
# Lets check the zscore of each variable in our dataset and remove the outliers having zscore value greater than 3.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
df[(z>3).all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# We can see that there are no outliers having zscore value greater than the threshold value 3. So we are not removing them.

# %% [markdown]
# # Removing Skewness

# %% [markdown]
# - Skewness indicates the asymmetry in the probability distribution in our dataset.
# - Skewness exists when the distribution curve is distorted or asymmetrical, meaning that there are more data points on one side of the median than on the other.
# - Many models do not work well if there is skewness as the tall tail acts as outliers in this case.

# %%
x=df.drop('W',axis=1)
y=df['W']

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# 12  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2   12
# 13  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6   12
# 14  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5   15
# 15  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1   15
# 16  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0   13
# 17  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6   21
# 18  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1    7
# 19  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2    8
# 20  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1   14
# 21  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4   13
# 22  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0   12
# 23  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3   10
# 24  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1    7
# 25  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6   21
# 26  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7   18
# 27  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1   12
# 28  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1    6
# 29  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4    4
#
#     SV    E
# 0   56   88
# 1   45   86
# 2   38   79
# 3   37  101
# 4   35   86
# 5   34   88
# 6   48   93
# 7   43   77
# 8   60   95
# 9   40   97
# 10  45  119
# 11  39   85
# 12  46   93
# 13  45   94
# 14  28  126
# 15  62   96
# 16  54  122
# 17  48  111
# 18  40  116
# 19  35   90
# 20  50   88
# 21  41   90
# 22  35   77
# 23  44   90
# 24  35  117
# 25  47   75
# 26  41   78
# 27  44   86
# 28  41   92
# 29  36   95

# %%
x.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# We can see that skewness is high in some of the columns like CG, SHO, SV and E. So we will be using Power transform to remove the outliers.

# %%
x['CG']
# Out:
# 0      2
# 1      2
# 2     11
# 3      7
# 4      7
# 5      7
# 6      3
# 7      0
# 8      1
# 9      3
# 10     5
# 11     5
# 12     2
# 13     6
# 14     5
# 15     1
# 16     0
# 17     6
# 18     1
# 19     2
# 20     1
# 21     4
# 22     0
# 23     3
# 24     1
# 25     6
# 26     7
# 27     1
# 28     1
# 29     4
# Name: CG, dtype: int64

# %% [markdown]
# We cannot apply boxcox transformation to remove skewness as there are zero values in this column and boxcox works on stricly positive values.
#
# So we will be using yeo transformation in this case.

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson', standardize=False)
x_new=pt.fit_transform(x)

# %%
x_trans=pd.DataFrame(x_new,columns=x.columns)

# %%
x_trans.skew()
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# RA    -0.008082
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.000000
# dtype: float64

# %%
x_trans
# Out:
#            R        AB         H             2B         3B        HR  \
# 0   0.120387  0.120387  0.120387  336128.055182  14.633107  5.146456
# 1   0.120387  0.120387  0.120387  278151.529845  15.090944  5.270805
# 2   0.120387  0.120387  0.120387  344162.322895  11.423265  5.161834
# 3   0.120387  0.120387  0.120387  239337.240000  10.884646  5.122978
# 4   0.120387  0.120387  0.120387  307606.040696  16.202133  5.235664
# 5   0.120387  0.120387  0.120387  357798.098947   7.924496  5.700955
# 6   0.120387  0.120387  0.120387  266383.828233   8.559676  5.602927
# 7   0.120387  0.120387  0.120387  209885.203155   8.867941  5.628258
# 8   0.120387  0.120387  0.120387  280540.539865  12.205654  5.344391
# 9   0.120387  0.120387  0.120387  320388.768662  12.460222  5.304862
# 10  0.120387  0.120387  0.120387  282941.411118  12.205654  5.376285
# 11  0.120387  0.120387  0.120387  280540.539865  10.609727  5.691533
# 12  0.120387  0.120387  0.120387  203864.389888   9.170537  5.401154
# 13  0.120387  0.120387  0.120387  243728.590634   9.467818  5.528762
# 14  0.120387  0.120387  0.120387  278151.529845  15.540918  5.199366
# 15  0.120387  0.120387  0.120387  305085.671247  13.930469  5.130860
# 16  0.120387  0.120387  0.120387  315239.438176  10.884646  5.154172
# 17  0.120387  0.120387  0.120387  266383.828233  11.687312  5.369979
# 18  0.120387  0.120387  0.120387  271055.504502  12.711890  5.191961
# 19  0.120387  0.120387  0.120387  232836.894393  10.884646  5.344391
# 20  0.120387  0.120387  0.120387  322981.600746   7.924496  5.407285
# 21  0.120387  0.120387  0.120387  250402.634416   6.564574  5.407285
# 22  0.120387  0.120387  0.120387  190209.430345  14.166894  4.988537
# 23  0.120387  0.120387  0.120387  220146.567887   8.245344  4.793440
# 24  0.120387  0.120387  0.120387  266383.828233  13.450594  5.074467
# 25  0.120387  0.120387  0.120387  245941.652703  10.609727  5.466795
# 26  0.120387  0.120387  0.120387  305085.671247  13.930469  5.122978
# 27  0.120387  0.120387  0.120387  307606.040696  15.983490  5.256882
# 28  0.120387  0.120387  0.120387  239337.240000  13.206972  5.214029
# 29  0.120387  0.120387  0.120387  271055.504502  16.202133  5.460986
#
#            BB            SO        SB          RA          ER       ERA  \
# 0   11.744734  21714.771712  8.370123  228.934244  229.612644  3.160220
# 1   12.219198  32234.374951  7.270817  245.889490  245.820118  3.418248
# 2   12.917532  28204.491625  7.829348  228.644361  224.259881  3.114357
# 3   11.928714  30972.162119  7.194376  246.174450  242.721975  3.350247
# 4   12.345921  32042.036103  7.731019  274.853567  274.241844  3.844231
# 5   13.165763  27983.948372  7.893462  237.303865  232.122095  3.213600
# 6   13.060033  30820.328498  6.995536  245.319336  245.510691  3.388052
# 7   12.047208  34848.948642  6.109238  243.892582  243.652326  3.403155
# 8   12.195032  34022.047360  7.861545  229.224041  230.554391  3.167854
# 9   12.522050  27873.896524  7.308418  260.888195  258.434612  3.598572
# 10  12.706049  31048.173519  8.285222  255.252817  254.142768  3.546127
# 11  12.581741  37288.660246  8.818867  222.244723  220.464522  3.037690
# 12  12.186947  27947.248127  6.511998  238.739827  238.681333  3.319956
# 13  12.522050  35046.817947  7.232806  253.273515  253.221019  3.486040
# 14  12.499462  26817.656856  7.560968  254.122233  249.218192  3.470993
# 15  12.727639  32349.965009  7.232806  194.684510  190.204712  2.547647
# 16  12.392535  34493.740126  8.198379  215.801353  207.707162  2.759216
# 17  13.146119  42501.655328  8.109490  219.321452  212.191319  2.875730
# 18  11.996815  33591.596172  7.764091  256.382222  254.756859  3.576110
# 19  12.655272  31888.445585  9.130592  261.169207  260.269171  3.613535
# 20  12.596543  33240.790200  6.464324  220.784228  215.700016  2.929864
# 21  12.958693  35364.195989  6.740507  227.193643  222.047653  3.076059
# 22  11.672545  27947.248127  8.587753  239.600427  241.169645  3.380496
# 23  12.469169  26384.644345  7.232806  262.853783  259.657968  3.673287
# 24  11.780382  32620.218784  7.893462  276.518049  275.147601  3.881231
# 25  13.119799  32003.615075  6.827680  215.507403  214.425587  2.937585
# 26  12.361513  28278.136079  8.049038  224.867938  228.355659  3.152583
# 27  12.611296  34100.510194  9.084181  249.587942  247.674884  3.395605
# 28  12.113517  34690.926240  7.697643  254.687673  246.438714  3.433331
# 29  11.789249  32968.803547  8.168982  286.181136  290.149369  4.138683
#
#           CG       SHO        SV         E
# 0   1.261954  4.033641  2.310585  0.503759
# 1   1.261954  5.263553  2.246884  0.503756
# 2   3.429637  4.676362  2.194886  0.503743
# 3   2.717248  4.362947  2.186461  0.503775
# 4   2.717248  5.263553  2.168705  0.503756
# 5   2.717248  4.676362  2.159336  0.503759
# 6   1.652938  2.486740  2.266094  0.503766
# 7   0.000000  4.676362  2.233142  0.503739
# 8   0.755958  5.263553  2.329874  0.503768
# 9   1.652938  4.676362  2.210919  0.503771
# 10  2.253326  4.362947  2.246884  0.503789
# 11  2.253326  5.540378  2.203034  0.503754
# 12  1.261954  5.263553  2.253465  0.503766
# 13  2.497814  5.263553  2.246884  0.503767
# 14  2.253326  6.066172  2.094663  0.503793
# 15  0.755958  6.066172  2.338908  0.503770
# 16  0.000000  5.540378  2.300264  0.503791
# 17  2.497814  7.473432  2.266094  0.503784
# 18  0.755958  3.685724  2.210919  0.503787
# 19  1.261954  4.033641  2.168705  0.503762
# 20  0.755958  5.807604  2.278066  0.503759
# 21  1.975911  5.540378  2.218557  0.503762
# 22  0.000000  5.263553  2.168705  0.503739
# 23  1.652938  4.676362  2.240113  0.503762
# 24  0.755958  3.685724  2.168705  0.503788
# 25  2.497814  7.473432  2.259866  0.503734
# 26  2.717248  6.797348  2.218557  0.503741
# 27  0.755958  5.263553  2.240113  0.503756
# 28  0.755958  3.315591  2.218557  0.503765
# 29  1.975911  2.486740  2.177740  0.503768

# %% [markdown]
# # Finding the best random state

# %%
#Finding best random_state
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
maxAccu=0
maxRS=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_trans,y,test_size=.3,random_state=i)
    LR=LinearRegression()
    LR.fit(x_train,y_train)
    predrf=LR.predict(x_test)
    acc=LR.score(x_train,y_train)
    acc=acc*100
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
    
print('Best accuracy is ',maxAccu, 'on random state ',maxRS)
# Out:
# Best accuracy is  98.3728693687895 on random state  31

# %% [markdown]
# # Finding the best fit model

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=31)

from sklearn.model_selection import train_test_split ,  cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import  RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.linear_model import  Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error as mae
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_validate

model_reg = [RandomForestRegressor(), SVR(), DecisionTreeRegressor(),KNeighborsRegressor(),LinearRegression(normalize=True),Ridge(alpha=0.05,normalize=True)]
df_result=pd.DataFrame(columns=['Model','Score','Mean Absolute Error','RMSE','R2 Score'])


for model in model_reg:
    m = model
    test_string=str(m)
    spl_word='('
    print('Model: ',m)
    m.fit(x_train, y_train)
    pred = m.predict(x_test)
    acc=m.score(x_train,y_train)
    acc_final=acc
    print('Score: ', acc_final)
    rmse = np.mean(np.sqrt(-cross_val_score(model, x_test, y_test, cv=5, scoring="neg_mean_squared_error")))
    r2_scr=r2_score(y_test,pred)
    #scr=cross_val_score(m,x,y,cv=5,scoring)
    #scr=np.sqrt(np.abs(scr['test_score']))
    #scr_final=np.mean(scr)
    #scr_final=scr.mean()
    print('RMSEe: ',rmse)
    #diff=(acc_final-scr_final)
    mean_abs_error=mae(y_test,pred)
    #print('Difference between cross validation score and accuracy is ', diff)
    print('------------------------------------------------')
    df_result=df_result.append({'Model':test_string,'Score':acc_final,'Mean Absolute Error':mean_abs_error,'RMSE':rmse,'R2 Score':r2_scr}, ignore_index=True)

print(df_result)
# Out:
# Model:  RandomForestRegressor()
# Score:  0.9540484281062124
# RMSEe:  10.402411036110138
# ------------------------------------------------
# Model:  SVR()
# Score:  -0.015902513102087568
# RMSEe:  9.641347509295619
# ------------------------------------------------
# Model:  DecisionTreeRegressor()
# Score:  1.0
# RMSEe:  15.050487436308043
# ------------------------------------------------
# Model:  KNeighborsRegressor()
# Score:  0.5971492985971942
# RMSEe:  8.497992862621922
# ------------------------------------------------
# Model:  LinearRegression(normalize=True)
# Score:  0.9958056949429392
# RMSEe:  6.891053168021676
# ------------------------------------------------
# Model:  Ridge(alpha=0.05, normalize=True)
# Score:  0.9796414097918363
# RMSEe:  7.677501738066459
# ------------------------------------------------
#                                Model     Score  Mean Absolute Error  \
# 0            RandomForestRegressor()  0.954048             6.232222
# 1                              SVR() -0.015903             7.439644
# 2            DecisionTreeRegressor()  1.000000             6.555556
# 3              KNeighborsRegressor()  0.597149             5.822222
# 4   LinearRegression(normalize=True)  0.995806             5.841517
# 5  Ridge(alpha=0.05, normalize=True)  0.979641             4.668402
#
#         RMSE  R2 Score
# 0  10.402411  0.400319
# 1   9.641348 -0.123378
# 2  15.050487  0.309432
# 3   8.497993  0.258924
# 4   6.891053  0.318845
# 5   7.677502  0.484306

# %%
df_result
# Out:
#                                Model     Score  Mean Absolute Error  \
# 0            RandomForestRegressor()  0.954048             6.232222
# 1                              SVR() -0.015903             7.439644
# 2            DecisionTreeRegressor()  1.000000             6.555556
# 3              KNeighborsRegressor()  0.597149             5.822222
# 4   LinearRegression(normalize=True)  0.995806             5.841517
# 5  Ridge(alpha=0.05, normalize=True)  0.979641             4.668402
#
#         RMSE  R2 Score
# 0  10.402411  0.400319
# 1   9.641348 -0.123378
# 2  15.050487  0.309432
# 3   8.497993  0.258924
# 4   6.891053  0.318845
# 5   7.677502  0.484306

# %% [markdown]
# - The best possible value for score in linear regression is 1. We have to choose the model which is more closer to 1.
# - Mean Absolute Error indicates the difference between the real value and the predicted value. So it should be minimum.
# - Root Mean Squared Error (RMSE) is square root of the variance, which indicates how close observed data points are to the predicted data points. So it should be also minimum for a good fit model.
# - R2 score indicates the goodness of fit for a model. So higher the R2 score of the model, better the performance.
#
# Now, we can see in the above dataframe that Ridge Regression is the best fit model for this dataset as it has maximum score and R2 score value (closer to 1) and with least RMSE.

# %% [markdown]
# # Finalizing the Model

# %%
#Random Forest is our best fit model.
rr = Ridge()
rr.fit(x_train , y_train)
rr.score(x_train , y_train)
# Out:
# 0.9870596117323426

# %%
y_pred = rr.predict(x_test)

# %%
print("Predicted result: ",y_pred)
print("Actual result : ", y_test)
# Out:
# Predicted result:  [ 95.98731613  63.01940644  89.74017863  82.29145278 101.66981941
#   85.4456075   97.59173861  85.75583016  79.28730961]
# Actual result :  8      80
# 22     71
# 5      93
# 7      81
# 15    100
# 13     76
# 0      95
# 26     84
# 9      78
# Name: W, dtype: int64

# %%
#r2 score --> co-efficient of determination' is the proportion of the variance in the dependent variable that is predictable 
#from the independent variable(s). i.e. Change in y when x is being changed
from sklearn.metrics import r2_score
print(r2_score(y_test, pred))
# Out:
# 0.48430610834511

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params_Ridge = {'alpha': [1,0.1,0.01,0.001,0.0001,0] , "fit_intercept": [True, False]}

# %%
GCV=GridSearchCV(Ridge(),params_Ridge,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0],
#                          'fit_intercept': [True, False]})

# %%
GCV.best_params_ #printing the best parameters found by GridSearchCV
# Out:
# {'alpha': 0.0001, 'fit_intercept': False}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)

# %%
GCV.score(x_train,y_train)
# Out:
# 0.9915430803438855

# %% [markdown]
# Now we have got the best parameter using Grid Search CV, lets make the final model using these parameter.

# %% [markdown]
# **Saving the model**

# %%
ridge = Ridge(alpha=0.0001,fit_intercept=True)
ridge.fit(x_train , y_train)
ridge.score(x_train , y_train)
# Out:
# 0.9957864208642718

# %% [markdown]
# We have achieved accuracy of 99.5% in our final model.

# %%
import joblib
joblib.dump(ridge,'Baseball.obj')
# Out:
# ['Baseball.obj']
